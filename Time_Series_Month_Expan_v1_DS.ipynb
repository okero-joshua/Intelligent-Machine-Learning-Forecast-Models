# %% [markdown]
# # Hierarchical Sales Forecasting: Overall, Customer Segment & SubCategory
#
# This notebook implements grouped time series forecasting at three hierarchical levels:
# 1. **Overall** - Total quantity across all segments
# 2. **Customer Segment** - Aggregated by customer segments
# 3. **SubCategory** - Aggregated by product subcategories
#
# We'll use multiple forecasting approaches and ensure hierarchical consistency.

# %%
import mlflow 
mlflow.set_experiment("Time_Series_V1_DS")

# %%
# Import required libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from datetime import datetime, timedelta
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("Libraries imported successfully!")
print(f"Analysis run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 87, Finished, Available, Finished)
# Libraries imported successfully!
# Analysis run on: 2025-07-13 09:44:08

# %%
# Check whether running in Fabric or locally, and set the data location accordingly
if "AZURE_SERVICE" in os.environ:
    is_fabric = True
    data_location = "/lakehouse/default/Files/"
    print("Running in Fabric, setting data location to /lakehouse/default/Files/")
else:
    is_fabric = False
    data_location = ""
    print("Running locally, setting data location to current directory")
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 88, Finished, Available, Finished)
# Running in Fabric, setting data location to /lakehouse/default/Files/

# %%
# Load the combined sales economic data
data = pd.read_csv(data_location + 'forecasting/userProvidedData/combined_sales_economic_data_segmented.csv')
data['Date'] = pd.to_datetime(data['Date'])
data = data.sort_values('Date')

print("=== DATASET OVERVIEW ===")
print(f"Dataset shape: {data.shape}")
print(f"Date range: {data['Date'].min()} to {data['Date'].max()}")
print(f"Unique Customer Segments: {data['CustomerSegment'].nunique()}")
print(f"Unique SubCategories: {data['SubCategoryName'].nunique()}")
print(f"\nCustomer Segments: {sorted(data['CustomerSegment'].unique())}")
print(f"\nSubCategories: {sorted(data['SubCategoryName'].unique())}")
print(f"\nData types:")
print(data.dtypes)
print(f"\nFirst few rows:")
data.head()
# pd.set_option('display.max_columns', 100)
# print(data.tail())
# pd.reset_option('display.max_columns')
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 89, Finished, Available, Finished)
# === DATASET OVERVIEW ===
# Dataset shape: (6347, 48)
# Date range: 2015-01-01 00:00:00 to 2024-12-01 00:00:00
# Unique Customer Segments: 15
# Unique SubCategories: 19
#
# Customer Segments: ['B Customer - Norris', 'Brand Owners', 'Container Manufacturers', 'Distribution', 'Drum & Pail Manufacturers', 'Fillers', 'Global Strategic Accounts', 'Industrial Chemicals', 'InterCompany', 'Other', 'Pharmaceuticals & Nutraceuticals', 'Small Customers < $250k / year', 'Tier 1 Accounts', 'Tier 2 Accounts', 'Unknown Segment']
#
# SubCategories: ['Components', 'Dispensing Pumps (10cc to 30cc)', 'Drum Faucets', 'Freight', 'Gaskets & Vents', 'Non-Product Sales', 'Other', 'Overcaps', 'Plugs', 'Press-Fit Closures', 'Proprietary Molded Solutions', 'Pull Out Spout Closures', 'Purchased', 'Screw Closures', 'Special Caps', 'Specialty Closures', 'Tools', 'Unknown SubCategory', 'Wrenches']
#
# Data types:
# Date                            datetime64[ns]
# CustomerSegment                         object
# SubCategoryName                         object
# Total_Quantity                         float64
# Avg_Quantity_Per_Transaction           float64
# Transaction_Count                        int64
# Unique_Customers                         int64
# Unique_Products                          int64
# PP_Spot                                float64
# Resin                                  float64
# WTI_Crude_Oil                          float64
# Natural_Gas                            float64
# Oil-to-resin                           float64
# Regional_electricity                   float64
# Energy_Average                         float64
# Diesel                                 float64
# PPI_Freight                            float64
# PPI_Delivery                           float64
# Beverage                               float64
# PPI_Pharmaceuticals                    float64
# Household_consumption                  float64
# packaging                              float64
# PMI_Data                               float64
# Factory_Utilization                    float64
# Capacity_Utilization                   float64
# Electricity Price                      float64
# Electricity Price (Lag6)               float64
# Gas Price                              float64
# Gas Price (Lag6)                       float64
# Energy_Composite                       float64
# German_Energy_Composite                float64
# Manufacturing_Health                   float64
# Cost_Pressure                          float64
# Market_Demand_Proxy                    float64
# Energy_Volatility                      float64
# German_Energy_Premium                  float64
# Total_Quantity_YoY                     float64
# Total_Quantity_MoM                     float64
# Total_Quantity_3MA                     float64
# Total_Quantity_6MA                     float64
# Total_Quantity_12MA                    float64
# Month                                    int64
# Quarter                                  int64
# Year                                     int64
# Economic_Momentum                      float64
# Cost_Efficiency                        float64
# Monthly_Total_Market                   float64
# Market_Share_Percent                   float64
# dtype: object
#
# First few rows:
#            Date            CustomerSegment          SubCategoryName  \
# 1879 2015-01-01  Drum & Pail Manufacturers       Specialty Closures
# 2710 2015-01-01       Industrial Chemicals       Press-Fit Closures
# 664  2015-01-01    Container Manufacturers       Specialty Closures
# 779  2015-01-01               Distribution          Gaskets & Vents
# 5932 2015-01-01            Tier 1 Accounts  Pull Out Spout Closures
#
#       Total_Quantity  Avg_Quantity_Per_Transaction  Transaction_Count  \
# 1879        239000.0                      119500.0                  2
# 2710        344620.0                       86155.0                  4
# 664         111600.0                       55800.0                  2
# 779         220000.0                      110000.0                  2
# 5932         62200.0                       31100.0                  2
#
#       Unique_Customers  Unique_Products  PP_Spot   Resin  ...  \
# 1879                 1                2    278.0  8075.0  ...
# 2710                 4                3    278.0  8075.0  ...
# 664                  2                1    278.0  8075.0  ...
# 779                  2                1    278.0  8075.0  ...
# 5932                 1                2    278.0  8075.0  ...
#
#       Total_Quantity_3MA  Total_Quantity_6MA  Total_Quantity_12MA  Month  \
# 1879                 NaN                 NaN                  NaN      1
# 2710                 NaN                 NaN                  NaN      1
# 664                  NaN                 NaN                  NaN      1
# 779                  NaN                 NaN                  NaN      1
# 5932                 NaN                 NaN                  NaN      1
#
#       Quarter  Year  Economic_Momentum  Cost_Efficiency  Monthly_Total_Market  \
# 1879        1  2015        5998.551387         3.677666            22965664.0
# 2710        1  2015        4855.595447         3.677666            22965664.0
# 664         1  2015        5945.231637         3.677666            22965664.0
# 779         1  2015        5934.825422         3.677666            22965664.0
# 5932        1  2015        5720.006260         3.677666            22965664.0
#
#       Market_Share_Percent
# 1879              1.040684
# 2710              1.500588
# 664               0.485943
# 779               0.957952
# 5932              0.270839
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Data Preparation for Hierarchical Forecasting
#
# We'll create three levels of aggregation:
# 1. **Level 0 (Overall)**: Total quantity across all segments and subcategories
# 2. **Level 1 (Customer Segment)**: Aggregated by customer segment
# 3. **Level 2 (SubCategory)**: Aggregated by product subcategory

# %%
# Create hierarchical aggregations
print("=== CREATING HIERARCHICAL AGGREGATIONS ===")

# Holds columns and their aggregation functions
column_aggregations = {
    'Total_Quantity': 'sum',
    'Transaction_Count': 'sum',
    'Unique_Customers': 'sum',
    'Unique_Products': 'sum',
    # Economic indicators (take mean as they're external factors)
    'PP_Spot': 'mean',
    'Resin': 'mean',
    'WTI_Crude_Oil': 'mean',
    'Natural_Gas': 'mean',
    'Electricity Price': 'mean',
    'Gas Price': 'mean',
    'Energy_Average': 'mean',
    'PPI_Freight': 'mean',
    'PMI_Data': 'mean',
    'Factory_Utilization': 'mean',
    'Capacity_Utilization': 'mean',
    'Beverage': 'mean', # Additional economic indicator
    'Household_consumption': 'mean',
    'packaging': 'mean',
    'Diesel': 'mean',
    'PPI_Delivery': 'mean',
    'Oil-to-resin': 'mean',
    'Electricity Price (Lag6)': 'mean',
    'Gas Price (Lag6)': 'mean'
}

# Define exogenous variables for modeling
exog_vars = [
    'PP_Spot',
    'Resin',
    'PMI_Data',
    'Natural_Gas',
    'WTI_Crude_Oil',
    'Factory_Utilization',
    'packaging',
    'Energy_Average',
    'Electricity Price (Lag6)',
    'Gas Price (Lag6)'
]

    # 'PPI_Delivery' slightly negative
    # 'PMI_Data', major positive
    # 'PPI_Freight', negative
    # 'Factory_Utilization',
    # 'Capacity_Utilization', negative
    # 'Beverage', minor negative
    # 'Household_consumption', major negative
    # 'packaging' minor positive
    # 'Diesel', minor positive
    # 'Natural_Gas' major positive
    # 'Electricity Price (Lag6)', positive
    # 'Gas Price (Lag6)' positive


# Level 0: Overall aggregation (sum across all segments and subcategories)
overall_ts = data.groupby('Date').agg(column_aggregations).reset_index()
overall_ts['Level'] = 'Overall'
overall_ts['Segment'] = 'Total'

# # Level 1: Customer Segment aggregation
segment_ts = data.groupby(['Date', 'CustomerSegment']).agg(column_aggregations).reset_index()
segment_ts['Level'] = 'CustomerSegment'
segment_ts['Segment'] = segment_ts['CustomerSegment']

# # Level 2: SubCategory aggregation
subcategory_ts = data.groupby(['Date', 'SubCategoryName']).agg(column_aggregations).reset_index()
subcategory_ts['Level'] = 'SubCategoryName'
subcategory_ts['Segment'] = subcategory_ts['SubCategoryName']

print(f"Overall time series shape: {overall_ts.shape}")
print(f"Customer segment time series shape: {segment_ts.shape}")
print(f"SubCategory time series shape: {subcategory_ts.shape}")

# Display summary statistics
print("\n=== LEVEL SUMMARY ===")
print(f"Overall total quantity range: {overall_ts['Total_Quantity'].min():,.0f} - {overall_ts['Total_Quantity'].max():,.0f}")
print(f"Customer segments: {segment_ts['CustomerSegment'].unique()}")
print(f"SubCategories: {subcategory_ts['SubCategoryName'].unique()}")

print(overall_ts.head())
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 90, Finished, Available, Finished)
# === CREATING HIERARCHICAL AGGREGATIONS ===
# Overall time series shape: (120, 26)
# Customer segment time series shape: (1444, 27)
# SubCategory time series shape: (1663, 27)
#
# === LEVEL SUMMARY ===
# Overall total quantity range: 12,565,334 - 33,525,018
# Customer segments: ['B Customer - Norris' 'Brand Owners' 'Container Manufacturers'
#  'Distribution' 'Drum & Pail Manufacturers' 'Fillers'
#  'Industrial Chemicals' 'InterCompany' 'Other'
#  'Pharmaceuticals & Nutraceuticals' 'Small Customers < $250k / year'
#  'Tier 1 Accounts' 'Unknown Segment' 'Global Strategic Accounts'
#  'Tier 2 Accounts']
# SubCategories: ['Dispensing Pumps (10cc to 30cc)' 'Drum Faucets' 'Freight'
#  'Gaskets & Vents' 'Non-Product Sales' 'Other' 'Overcaps' 'Plugs'
#  'Press-Fit Closures' 'Pull Out Spout Closures' 'Purchased'
#  'Screw Closures' 'Specialty Closures' 'Tools' 'Wrenches' 'Components'
#  'Unknown SubCategory' 'Proprietary Molded Solutions' 'Special Caps']
#         Date  Total_Quantity  Transaction_Count  Unique_Customers  \
# 0 2015-01-01      22965664.0                253               201
# 1 2015-02-01      23124609.0                288               229
# 2 2015-03-01      27568361.0                269               222
# 3 2015-04-01      25905304.0                284               235
# 4 2015-05-01      22517479.0                214               181
#
#    Unique_Products  PP_Spot   Resin  WTI_Crude_Oil  Natural_Gas  \
# 0              141    278.0  8075.0          68.44     2.580000
# 1              155    278.0  8075.0          68.44     2.580000
# 2              147    278.0  8075.0          68.44     2.580000
# 3              158    278.0  8075.0          68.44     2.589000
# 4              131    278.0  8075.0          68.44     2.847742
#
#    Electricity Price  ...  Beverage  Household_consumption  packaging  \
# 0             0.2276  ...   98.2246              11933.651      147.9
# 1             0.2276  ...   98.2246              11933.651      147.9
# 2             0.2276  ...   98.2246              11933.651      147.9
# 3             0.2276  ...   98.0728              11933.651      147.9
# 4             0.2276  ...   98.0724              11933.651      147.9
#
#      Diesel  PPI_Delivery  Oil-to-resin  Electricity Price (Lag6)  \
# 0  2.780000         143.8         278.0                    0.2302
# 1  2.780000         143.8         278.0                    0.2302
# 2  2.780000         143.8         278.0                    0.2302
# 3  2.784133         144.2         278.0                    0.2302
# 4  2.880097         144.1         278.0                    0.2302
#
#    Gas Price (Lag6)    Level  Segment
# 0             15.23  Overall    Total
# 1             15.23  Overall    Total
# 2             15.23  Overall    Total
# 3             15.23  Overall    Total
# 4             15.23  Overall    Total
#
# [5 rows x 26 columns]

# %%
# === SPLIT DATA INTO TRAIN/TEST BASED ON TIME === USING 7 YEAR'S DATA

train_start_date = pd.to_datetime("2015-01-01")
train_end_date = pd.to_datetime("2023-12-01")
test_dates = pd.to_datetime(["2024-01-01", "2024-02-01"])

# Split overall data
overall_train = overall_ts[(overall_ts['Date'] >= train_start_date) & (overall_ts['Date'] <= train_end_date)].copy()
overall_test = overall_ts[overall_ts['Date'].isin(test_dates)].copy()

# Split customer segment data
segment_train = segment_ts[(segment_ts['Date'] >= train_start_date) & (segment_ts['Date'] <= train_end_date)].copy()
segment_test = segment_ts[segment_ts['Date'].isin(test_dates)].copy()

# Split subcategory data
subcategory_train = subcategory_ts[(subcategory_ts['Date'] >= train_start_date) & (subcategory_ts['Date'] <= train_end_date)].copy()
subcategory_test = subcategory_ts[subcategory_ts['Date'].isin(test_dates)].copy()

print("Training period:", overall_train['Date'].min(), "to", overall_train['Date'].max())
print("Testing period:", overall_test['Date'].min(), "to", overall_test['Date'].max())
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 91, Finished, Available, Finished)
# Training period: 2015-01-01 00:00:00 to 2023-12-01 00:00:00
# Testing period: 2024-01-01 00:00:00 to 2024-02-01 00:00:00

# %%
def walk_forward_split(data, start_train, end_train, horizon=2):
    """Generates train-test pairs with walk-forward strategy"""
    train_test_splits = []
    current_end = end_train

    while current_end + pd.DateOffset(months=horizon) <= data['Date'].max():
        train_data = data[(data['Date'] >= start_train) & (data['Date'] <= current_end)]
        test_data = data[(data['Date'] > current_end) & (data['Date'] <= current_end + pd.DateOffset(months=horizon))]
        train_test_splits.append((train_data.copy(), test_data.copy()))
        current_end += pd.DateOffset(months=1)

    return train_test_splits
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 92, Finished, Available, Finished)

# %%
# Set initial train window: Jan 2016 to Dec 2023, test horizon = 2 month
rolling_splits = walk_forward_split(overall_ts, pd.to_datetime("2015-01-01"), pd.to_datetime("2023-12-01"), horizon=2)
print(f"Generated {len(rolling_splits)} rolling train-test pairs.")
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 93, Finished, Available, Finished)
# Generated 11 rolling train-test pairs.

# %%
train, test = rolling_splits[0]

print("Train:")
display(train)

print("Test:")
display(test)
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 94, Finished, Available, Finished)
# Train:
# SynapseWidget(Synapse.DataFrame, 89f47495-fe3d-4c11-a8bf-740a055b9633)
# Test:
# SynapseWidget(Synapse.DataFrame, 8a7d0172-d09c-4546-bb3d-a25e34300024)

# %% [markdown]
# # Hierarchical Forecasting Implementation
#
# Functions defining the forecasting

# %% [markdown]
# ## Forecasting Models
#
# We'll implement multiple forecasting approaches:
# 1. **ARIMA** - Auto-regressive Integrated Moving Average
# 2. **SARIMA** - Seasonal ARIMA with economic indicators
# 3. **Exponential Smoothing** - Holt-Winters method
# 4. **Ensemble** - Weighted combination of methods

# %%
def forecast_arima(series, steps=12, order=(1,1,1)):
    """
    ARIMA forecasting with automatic order selection if needed
    """
    try:
        model = ARIMA(series, order=order)
        fitted_model = model.fit()
        forecast = fitted_model.forecast(steps=steps)
        conf_int = fitted_model.get_forecast(steps=steps).conf_int()
        return forecast, conf_int, fitted_model.aic
    except:
        # Try simpler model if original fails
        try:
            model = ARIMA(series, order=(1,0,1))
            fitted_model = model.fit()
            forecast = fitted_model.forecast(steps=steps)
            conf_int = fitted_model.get_forecast(steps=steps).conf_int()
            return forecast, conf_int, fitted_model.aic
        except:
            # Last resort - simple naive forecast
            last_value = series.iloc[-1]
            forecast = pd.Series([last_value] * steps)
            conf_int = pd.DataFrame({
                'lower Total_Quantity': forecast * 0.9,
                'upper Total_Quantity': forecast * 1.1
            })
            return forecast, conf_int, float('inf')

def forecast_sarima(series, exog=None, steps=12, order=(1,1,1), seasonal_order=(1,1,1,12)):
    """
    SARIMA forecasting with external regressors
    """
    try:
        model = SARIMAX(series, exog=exog, order=order, seasonal_order=seasonal_order)
        fitted_model = model.fit(disp=False)
        
        # For forecast, we need future exogenous variables
        # Use last known values as a simple assumption
        if exog is not None:
            future_exog = pd.DataFrame([exog.iloc[-1]] * steps)
            future_exog.index = pd.date_range(start=exog.index[-1] + pd.DateOffset(months=1), periods=steps, freq='MS')
        else:
            future_exog = None
            
        forecast = fitted_model.forecast(steps=steps, exog=future_exog)
        conf_int = fitted_model.get_forecast(steps=steps, exog=future_exog).conf_int()
        return forecast, conf_int, fitted_model.aic
    except:
        # Fallback to simple ARIMA
        return forecast_arima(series, steps, order)

def forecast_exponential_smoothing(series, steps=12, seasonal_periods=12):
    """
    Exponential Smoothing (Holt-Winters) forecasting
    """
    try:
        if len(series) >= 2 * seasonal_periods:
            model = ExponentialSmoothing(series, trend='add', seasonal='add', seasonal_periods=seasonal_periods)
        else:
            model = ExponentialSmoothing(series, trend='add', seasonal=None)
        
        fitted_model = model.fit()
        forecast = fitted_model.forecast(steps=steps)
        
        # Simple confidence intervals based on residuals
        residuals = fitted_model.resid
        std_resid = residuals.std()
        conf_int = pd.DataFrame({
            'lower Total_Quantity': forecast - 1.96 * std_resid,
            'upper Total_Quantity': forecast + 1.96 * std_resid
        })
        
        return forecast, conf_int, fitted_model.aic
    except:
        # Fallback to ARIMA
        return forecast_arima(series, steps)

def ensemble_forecast(forecasts, aics=None):
    """
    Create ensemble forecast from multiple methods (weighted by inverse AIC)
    """
    weights = []

    if aics is None:
        weights = [1/len(forecasts)] * len(forecasts)
    else:
        weights = [1/aic if aic != float('inf') else 0 for aic in aics]
        total_weight = sum(weights)
        if total_weight > 0:
            weights = [w/total_weight for w in weights]
        else:
            weights = [1/3, 1/3, 1/3]

    print(f"Model weights - ARIMA: {weights[0]:.3f}, SARIMA: {weights[1]:.3f}, EXP: {weights[2]:.3f}")
    
    ensemble = sum(f * w for f, w in zip(forecasts, weights))
    return ensemble

print("Forecasting functions defined successfully!")
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 95, Finished, Available, Finished)
# Forecasting functions defined successfully!

# %% [markdown]
# ## Hierarchical Forecasting Functions

# %%
def forecast_overall(data, exog_vars, forecast_steps, forecast_dates):
    """
    Generate overall forecasts using multiple methods and ensemble approach
    
    Parameters:
    - data: DataFrame with overall time series data
    - exog_vars: List of exogenous variables to use in forecasting
    - forecast_steps: Number of steps to forecast
    - forecast_dates: Date range for forecasts
    
    Returns:
    - DataFrame with all forecast methods and ensemble result
    """
    print("=== LEVEL 0: OVERALL FORECASTING ===")
    
    # Prepare overall data
    overall_series = data.set_index('Date')['Total_Quantity']
    overall_exog = data.set_index('Date')[exog_vars]
    
    # Generate forecasts using different methods
    print("Generating ARIMA forecast...")
    overall_arima_forecast, overall_arima_conf, overall_arima_aic = forecast_arima(overall_series, forecast_steps)
    
    print("Generating SARIMA forecast...")
    overall_sarima_forecast, overall_sarima_conf, overall_sarima_aic = forecast_sarima(overall_series, overall_exog, forecast_steps)
    
    print("Generating Exponential Smoothing forecast...")
    overall_exp_forecast, overall_exp_conf, overall_exp_aic = forecast_exponential_smoothing(overall_series, forecast_steps)
    
    # Create ensemble forecast
    aics = [overall_arima_aic, overall_sarima_aic, overall_exp_aic]    
    overall_ensemble_forecast = ensemble_forecast(
        [overall_arima_forecast, overall_sarima_forecast, overall_exp_forecast], 
        aics
    )
    
    # Store overall forecasts
    overall_forecasts = pd.DataFrame({
        'Date': forecast_dates,
        'ARIMA': overall_arima_forecast.values,
        'SARIMA': overall_sarima_forecast.values,
        'ExpSmoothing': overall_exp_forecast.values,
        'Ensemble': overall_ensemble_forecast.values,
        'Level': 'Overall',
        'Segment': 'Total'
    })
    
    print(f"Overall forecast range: {overall_ensemble_forecast.min():,.0f} - {overall_ensemble_forecast.max():,.0f}")
    
    return overall_forecasts
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 96, Finished, Available, Finished)

# %%
def forecast_hierarchical_level(data, level_column, level_name, exog_vars, forecast_steps, forecast_dates):
    """
    Generic function to forecast at any hierarchical level (segments or subcategories)
    
    Parameters:
    - data: DataFrame with the time series data for the level
    - level_column: Column name that contains the grouping variable (e.g., 'CustomerSegment', 'SubCategoryName')
    - level_name: Name for the level (e.g., 'CustomerSegment', 'SubCategoryName')
    - exog_vars: List of exogenous variables to use in forecasting
    - forecast_steps: Number of steps to forecast
    - forecast_dates: Date range for forecasts
    
    Returns:
    - DataFrame with forecasts for all groups in the level
    """
    print(f"\n=== {level_name.upper()} FORECASTING ===")
    
    forecasts_list = []
    
    for group in data[level_column].unique():
        print(f"\nForecasting for {level_name.lower()}: {group}")
        
        # Filter data for this group
        group_data = data[data[level_column] == group].set_index('Date')
        group_series = group_data['Total_Quantity']
        group_exog = group_data[exog_vars]
        
        if len(group_series) < 3:  # Need minimum data points
            print(f"  Insufficient data for {group}, using naive forecast")
            group_ensemble = pd.Series([group_series.mean()] * forecast_steps)
        else:
            # Generate forecasts
            arima_forecast, _, arima_aic = forecast_arima(group_series, forecast_steps)
            sarima_forecast, _, sarima_aic = forecast_sarima(group_series, group_exog, forecast_steps)
            exp_forecast, _, exp_aic = forecast_exponential_smoothing(group_series, forecast_steps)
            
            # Create ensemble
            aics = [arima_aic, sarima_aic, exp_aic]
            group_ensemble = ensemble_forecast(
                [arima_forecast, sarima_forecast, exp_forecast],
                aics
            )
        
        # Store forecast
        forecast_df = pd.DataFrame({
            'Date': forecast_dates,
            'Ensemble': group_ensemble.values,
            'Level': level_name,
            'Segment': group,
            level_column: group
        })
        
        forecasts_list.append(forecast_df)
        print(f"  Forecast range: {group_ensemble.min():,.0f} - {group_ensemble.max():,.0f}")
    
    # Combine all forecasts
    combined_forecasts = pd.concat(forecasts_list, ignore_index=True)
    
    print(f"\nTotal {level_name.lower()} forecasts generated: {len(forecasts_list)}")
    print(f"{level_name} forecast total range: {combined_forecasts['Ensemble'].min():,.0f} - {combined_forecasts['Ensemble'].max():,.0f}")
    
    return combined_forecasts
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 97, Finished, Available, Finished)

# %%
def hierarchical_reconciliation(overall_forecasts, segment_forecasts, subcategory_forecasts, 
                               segment_ts, subcategory_ts, forecast_dates):
    """
    Perform top-down hierarchical reconciliation to ensure forecast consistency
    
    Parameters:
    - overall_forecasts: DataFrame with overall level forecasts
    - segment_forecasts: DataFrame with customer segment forecasts
    - subcategory_forecasts: DataFrame with subcategory forecasts
    - segment_ts: Historical segment time series data
    - subcategory_ts: Historical subcategory time series data
    - forecast_dates: Date range for forecasts
    
    Returns:
    - Tuple of (reconciled_segment_forecasts, reconciled_subcategory_forecasts)
    """
    print("=== HIERARCHICAL RECONCILIATION ===")
    
    # Check consistency before reconciliation
    print("\nBefore Reconciliation:")
    for date in forecast_dates[:3]:  # Check first 3 dates
        overall_val = overall_forecasts[overall_forecasts['Date'] == date]['Ensemble'].iloc[0]
        segment_sum = segment_forecasts[segment_forecasts['Date'] == date]['Ensemble'].sum()
        subcat_sum = subcategory_forecasts[subcategory_forecasts['Date'] == date]['Ensemble'].sum()
        
        print(f"  {date.strftime('%Y-%m')}: Overall={overall_val:,.0f}, Segments Sum={segment_sum:,.0f}, SubCats Sum={subcat_sum:,.0f}")
    
    # Calculate historical proportions for reconciliation
    print("\nCalculating historical proportions...")
    
    # Customer segment proportions
    segment_props = {}
    for segment in segment_ts['CustomerSegment'].unique():
        segment_total = segment_ts[segment_ts['CustomerSegment'] == segment]['Total_Quantity'].sum()
        overall_total = segment_ts['Total_Quantity'].sum()
        segment_props[segment] = segment_total / overall_total
    
    # SubCategory proportions
    subcat_props = {}
    for subcat in subcategory_ts['SubCategoryName'].unique():
        subcat_total = subcategory_ts[subcategory_ts['SubCategoryName'] == subcat]['Total_Quantity'].sum()
        overall_total = subcategory_ts['Total_Quantity'].sum()
        subcat_props[subcat] = subcat_total / overall_total
    
    print(f"Customer Segment Proportions: {segment_props}")
    print(f"SubCategory Proportions: {subcat_props}")
    
    # Apply top-down reconciliation
    print("\nApplying top-down reconciliation...")
    
    # Reconcile segment forecasts
    segment_forecasts_reconciled = segment_forecasts.copy()
    for idx, row in segment_forecasts_reconciled.iterrows():
        overall_val = overall_forecasts[overall_forecasts['Date'] == row['Date']]['Ensemble'].iloc[0]
        segment_forecasts_reconciled.loc[idx, 'Ensemble_Reconciled'] = overall_val * segment_props[row['CustomerSegment']]
    
    # Reconcile subcategory forecasts
    subcategory_forecasts_reconciled = subcategory_forecasts.copy()
    for idx, row in subcategory_forecasts_reconciled.iterrows():
        overall_val = overall_forecasts[overall_forecasts['Date'] == row['Date']]['Ensemble'].iloc[0]
        subcategory_forecasts_reconciled.loc[idx, 'Ensemble_Reconciled'] = overall_val * subcat_props[row['SubCategoryName']]
    
    # Verify reconciliation
    print("\nAfter Reconciliation:")
    for date in forecast_dates[:3]:
        overall_val = overall_forecasts[overall_forecasts['Date'] == date]['Ensemble'].iloc[0]
        segment_sum = segment_forecasts_reconciled[segment_forecasts_reconciled['Date'] == date]['Ensemble_Reconciled'].sum()
        subcat_sum = subcategory_forecasts_reconciled[subcategory_forecasts_reconciled['Date'] == date]['Ensemble_Reconciled'].sum()
        
        print(f"  {date.strftime('%Y-%m')}: Overall={overall_val:,.0f}, Segments Sum={segment_sum:,.0f}, SubCats Sum={subcat_sum:,.0f}")
    
    print("\nReconciliation completed!")
    
    return segment_forecasts_reconciled, subcategory_forecasts_reconciled
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 98, Finished, Available, Finished)

# %% [markdown]
# # Running Hierarchical Forecasting

# %%
# Set forecasting parameters
FORECAST_STEPS = 2
START_DATE = pd.to_datetime("2024-01-01")
FORECAST_DATES = pd.date_range(start=START_DATE, periods=FORECAST_STEPS, freq='MS')
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 99, Finished, Available, Finished)

# %%
# Generate overall forecasts using the reusable function
overall_forecasts = forecast_overall(
    data=overall_train,
    exog_vars=exog_vars,
    forecast_steps=len(overall_test),
    forecast_dates=overall_test['Date'].unique()
)

overall_forecasts.head()
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 100, Finished, Available, Finished)
# Model weights - ARIMA: 0.309, SARIMA: 0.350, EXP: 0.342
# Overall forecast range: 21,490,913 - 22,086,739
#         Date         ARIMA        SARIMA  ExpSmoothing      Ensemble    Level  \
# 0 2024-01-01  1.954208e+07  2.576476e+07  2.062285e+07  2.208674e+07  Overall
# 1 2024-02-01  2.030101e+07  2.462188e+07  1.936304e+07  2.149091e+07  Overall
#
#   Segment
# 0   Total
# 1   Total

# %%
# === FORECAST CUSTOMER SEGMENT LEVEL ===
segment_forecasts = forecast_hierarchical_level(
    data=segment_train,
    level_column='CustomerSegment',
    level_name='CustomerSegment',
    exog_vars=exog_vars,
    forecast_steps=len(segment_test['Date'].unique()),
    forecast_dates=segment_test['Date'].unique()
)

segment_forecasts.head()
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 101, Finished, Available, Finished)
# 2025-07-13:09:44:57,710 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"39680588-6aee-4bef-9ad1-c31226942102","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:44:57,713 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:44:57,716 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:44:57,716 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:44:57,757 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:44:57,759 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:44:58,303 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"f3d8661a-6fdc-45c7-939d-3582bfe81336","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:44:58,305 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:44:58,307 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:44:58,308 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:44:58,341 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:44:58,343 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:04,118 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"1a990f00-ba9e-48ed-917d-fbffedfcea4c","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:04,120 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:04,122 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:04,123 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:04,155 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:04,158 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:04,779 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"ad6d73e9-b900-4c51-922c-fc7897fa5321","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:04,781 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:04,783 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:04,784 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:04,817 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:04,819 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:16,23 ERROR    [shared_platform_utils.py:45] list Notebook failed, status_code: 429, b'{"requestId":"afcccba2-22ec-4cf0-a366-9255e462d9dc","errorCode":"RequestBlocked","message":"Request is blocked by the upstream service until: 7/13/2025 9:45:38 AM (UTC)"}'
# 2025-07-13:09:45:16,24 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 29, in get_experiment_id
#     notebooks: List[O_PBIArtifact] = list_workspace_artifacts(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/shared_platform_utils.py", line 47, in list_workspace_artifacts
#     raise PublicApiException(resp.status_code, error_resp)
# synapse.ml.mlflow.model.shared_artifact.PublicApiException: (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e45c3cd0>)
# 2025-07-13:09:45:16,25 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e45c3cd0>)
# 2025-07-13:09:45:16,68 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:16,71 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:19,178 ERROR    [shared_platform_utils.py:45] list Notebook failed, status_code: 429, b'{"requestId":"7956272b-4bf4-446e-a8cb-b477957abc31","errorCode":"RequestBlocked","message":"Request is blocked by the upstream service until: 7/13/2025 9:45:38 AM (UTC)"}'
# 2025-07-13:09:45:19,178 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 29, in get_experiment_id
#     notebooks: List[O_PBIArtifact] = list_workspace_artifacts(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/shared_platform_utils.py", line 47, in list_workspace_artifacts
#     raise PublicApiException(resp.status_code, error_resp)
# synapse.ml.mlflow.model.shared_artifact.PublicApiException: (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7c36710>)
# 2025-07-13:09:45:19,180 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7c36710>)
# 2025-07-13:09:45:19,215 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:19,218 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# Model weights - ARIMA: 0.095, SARIMA: 0.808, EXP: 0.097
#   Forecast range: 353,212 - 357,408
#
# Total customersegment forecasts generated: 15
# CustomerSegment forecast total range: -14,912 - 10,111,638
#         Date       Ensemble            Level                  Segment  \
# 0 2024-01-01   -1949.629735  CustomerSegment      B Customer - Norris
# 1 2024-02-01  -14912.317284  CustomerSegment      B Customer - Norris
# 2 2024-01-01   38543.008276  CustomerSegment             Brand Owners
# 3 2024-02-01  138648.862713  CustomerSegment             Brand Owners
# 4 2024-01-01  209704.517845  CustomerSegment  Container Manufacturers
#
#            CustomerSegment
# 0      B Customer - Norris
# 1      B Customer - Norris
# 2             Brand Owners
# 3             Brand Owners
# 4  Container Manufacturers

# %%
# === FORECAST SUBCATEGORY LEVEL ===
subcategory_forecasts = forecast_hierarchical_level(
    data=subcategory_train,
    level_column='SubCategoryName',
    level_name='SubCategoryName',
    exog_vars=exog_vars,
    forecast_steps=len(subcategory_test['Date'].unique()),
    forecast_dates=subcategory_test['Date'].unique()
)

subcategory_forecasts.head()
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 102, Finished, Available, Finished)
# 2025-07-13:09:45:28,276 ERROR    [shared_platform_utils.py:45] list Notebook failed, status_code: 429, b'{"requestId":"8c4413d5-5486-4214-b687-ddeea2494738","errorCode":"RequestBlocked","message":"Request is blocked by the upstream service until: 7/13/2025 9:45:38 AM (UTC)"}'
# 2025-07-13:09:45:28,277 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 29, in get_experiment_id
#     notebooks: List[O_PBIArtifact] = list_workspace_artifacts(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/shared_platform_utils.py", line 47, in list_workspace_artifacts
#     raise PublicApiException(resp.status_code, error_resp)
# synapse.ml.mlflow.model.shared_artifact.PublicApiException: (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7a30890>)
# 2025-07-13:09:45:28,277 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7a30890>)
# 2025-07-13:09:45:28,318 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:28,321 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:30,546 ERROR    [shared_platform_utils.py:45] list Notebook failed, status_code: 429, b'{"requestId":"698b66cc-6623-4f17-b7c6-973a060b1b7f","errorCode":"RequestBlocked","message":"Request is blocked by the upstream service until: 7/13/2025 9:45:38 AM (UTC)"}'
# 2025-07-13:09:45:30,546 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 29, in get_experiment_id
#     notebooks: List[O_PBIArtifact] = list_workspace_artifacts(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/shared_platform_utils.py", line 47, in list_workspace_artifacts
#     raise PublicApiException(resp.status_code, error_resp)
# synapse.ml.mlflow.model.shared_artifact.PublicApiException: (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7bf01d0>)
# 2025-07-13:09:45:30,547 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7bf01d0>)
# 2025-07-13:09:45:30,586 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:30,588 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:37,513 ERROR    [shared_platform_utils.py:45] list Notebook failed, status_code: 429, b'{"requestId":"4343d9c5-aef5-4de5-a998-0a7bf08b032d","errorCode":"RequestBlocked","message":"Request is blocked by the upstream service until: 7/13/2025 9:45:38 AM (UTC)"}'
# 2025-07-13:09:45:37,514 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 29, in get_experiment_id
#     notebooks: List[O_PBIArtifact] = list_workspace_artifacts(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/shared_platform_utils.py", line 47, in list_workspace_artifacts
#     raise PublicApiException(resp.status_code, error_resp)
# synapse.ml.mlflow.model.shared_artifact.PublicApiException: (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e45c1510>)
# 2025-07-13:09:45:37,515 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e45c1510>)
# 2025-07-13:09:45:37,558 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:37,560 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:39,915 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"ac9a1b0d-902d-40dd-9db1-fd6cb7758f0c","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:39,917 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:39,919 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:39,920 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:39,953 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:39,955 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:40,473 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"20911a13-4e43-4d4c-a044-3225e9d7b891","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:40,475 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:40,477 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:40,478 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:40,511 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:40,513 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:43,676 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"6e99f5ee-23b9-48d8-aeea-299a1b84eb7b","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:43,678 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:43,680 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:43,681 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:43,717 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:43,719 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:44,266 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"d2744560-730a-4b00-8c61-7240dd14ec63","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:44,267 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:44,270 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:44,270 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:44,306 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:44,308 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:46,81 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"743fcf61-ab93-4d14-8f01-ec01fc5acbb5","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:46,83 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:46,85 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:46,86 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:46,128 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:46,130 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:46,682 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"2fb1c5ab-a241-4881-bf86-8a95bf6c4beb","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:46,684 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:46,686 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:46,687 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:46,718 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:46,720 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:49,347 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"9018c359-55ef-4738-a2e2-d98966449147","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:49,349 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:49,351 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:49,352 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:49,385 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:49,387 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:53,590 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"b913a99a-e1c0-4a34-b911-baa8fd94c6a9","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:53,592 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:53,594 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:53,595 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:53,630 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:53,632 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:54,202 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"8b264423-aa49-4ffc-97f6-245e6bb21f7b","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:54,204 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:54,206 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:54,207 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:54,242 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:54,244 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:57,328 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"3a8e3035-f156-4deb-ab05-75c28218829f","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:57,330 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:57,332 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:57,333 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:57,371 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:57,373 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:57,913 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"64954eb9-70b0-43c9-a341-e2653bb03696","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:45:57,915 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:57,918 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:57,919 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:45:57,956 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:45:57,959 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:46:00,361 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"84b4517d-308f-4b11-9bc0-9f3f908de5fb","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:46:00,363 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:46:00,365 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:46:00,366 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:46:00,920 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"56461ae5-a04c-49ff-8f62-0472e6b9597c","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:46:00,922 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:46:00,924 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:46:00,924 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:46:00,959 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:46:00,962 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:46:01,477 ERROR    [shared_platform_utils.py:82] Create MLExperiment failed, status_code: 400, b'{"requestId":"a3cc1664-3223-4082-aacc-79a946488409","errorCode":"ItemDisplayNameNotAvailableYet","message":"Requested \'Time_Series_Month_E_v1_DS\' is not available yet and is expected to become available in the upcoming minutes."}'
# 2025-07-13:09:46:01,479 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.tracking_store.TridentMLflowTrackingStore'>.create_experiment exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:46:01,481 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 52, in get_experiment_id
#     return mlflow.set_experiment(f"{artifact_name}").experiment_id
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/fluent.py", line 152, in set_experiment
#     experiment_id = client.create_experiment(experiment_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/client.py", line 599, in create_experiment
#     return self._tracking_client.create_experiment(name, artifact_location, tags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py", line 251, in create_experiment
#     return self.store.create_experiment(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 374, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/tracking_store.py", line 130, in create_experiment
#     experiment_id = artifact.properties.get("mlFlowExperimentId", artifact.properties.get("MLFlowExperimentId", None))
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:46:01,481 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception 'NoneType' object has no attribute 'properties'
# 2025-07-13:09:46:01,514 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:46:01,516 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# Model weights - ARIMA: 0.093, SARIMA: 0.812, EXP: 0.095
#   Forecast range: 30,651 - 89,867
#
# Total subcategoryname forecasts generated: 19
# SubCategoryName forecast total range: -11,359 - 9,654,248
#         Date      Ensemble            Level                          Segment  \
# 0 2024-01-01  9.420789e+06  SubCategoryName  Dispensing Pumps (10cc to 30cc)
# 1 2024-02-01  9.654248e+06  SubCategoryName  Dispensing Pumps (10cc to 30cc)
# 2 2024-01-01  3.182674e+03  SubCategoryName                     Drum Faucets
# 3 2024-02-01  3.884708e+03  SubCategoryName                     Drum Faucets
# 4 2024-01-01 -1.660947e+01  SubCategoryName                          Freight
#
#                    SubCategoryName
# 0  Dispensing Pumps (10cc to 30cc)
# 1  Dispensing Pumps (10cc to 30cc)
# 2                     Drum Faucets
# 3                     Drum Faucets
# 4                          Freight

# %%
print("Forecast Dates:")
print(FORECAST_DATES)

print("Overall Forecast Dates:")
print(overall_forecasts['Date'].unique())
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 103, Finished, Available, Finished)
# Forecast Dates:
# DatetimeIndex(['2024-01-01', '2024-02-01'], dtype='datetime64[ns]', freq='MS')
# Overall Forecast Dates:
# <DatetimeArray>
# ['2024-01-01 00:00:00', '2024-02-01 00:00:00']
# Length: 2, dtype: datetime64[ns]

# %% [markdown]
# ## Hierarchical Consistency & Reconciliation
#
# We need to ensure that the sum of forecasts at lower levels equals the forecast at higher levels. This is called hierarchical reconciliation.

# %%
# Apply hierarchical reconciliation using the reusable function
segment_forecasts_reconciled, subcategory_forecasts_reconciled = hierarchical_reconciliation(
    overall_forecasts=overall_forecasts,
    segment_forecasts=segment_forecasts,
    subcategory_forecasts=subcategory_forecasts,
    segment_ts=segment_ts,
    subcategory_ts=subcategory_ts,
    forecast_dates=FORECAST_DATES
)
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 104, Finished, Available, Finished)
# === HIERARCHICAL RECONCILIATION ===
#
# Before Reconciliation:
#   2024-01: Overall=22,086,739, Segments Sum=21,087,147, SubCats Sum=20,630,227
#   2024-02: Overall=21,490,913, Segments Sum=20,914,668, SubCats Sum=20,221,589
#
# Calculating historical proportions...
# Customer Segment Proportions: {'B Customer - Norris': 0.0008975761389418995, 'Brand Owners': 0.006056581314054652, 'Container Manufacturers': 0.02173432535814578, 'Distribution': 0.03415475720890335, 'Drum & Pail Manufacturers': 0.05520713124017283, 'Fillers': 0.0412775397666951, 'Industrial Chemicals': 0.1622479288340308, 'InterCompany': 0.39784312281718315, 'Other': 0.011282463729157232, 'Pharmaceuticals & Nutraceuticals': 0.007378470047537353, 'Small Customers < $250k / year': 0.1932159427613124, 'Tier 1 Accounts': 0.06522179239364899, 'Unknown Segment': 0.0018964271929287446, 'Global Strategic Accounts': 0.0004271694579631516, 'Tier 2 Accounts': 0.0011587717393245444}
# SubCategory Proportions: {'Dispensing Pumps (10cc to 30cc)': 0.35729925448705135, 'Drum Faucets': 0.00027874963747272083, 'Freight': 7.058515311843831e-07, 'Gaskets & Vents': 0.006602788263813672, 'Non-Product Sales': 0.00023611854375173567, 'Other': 0.000269235421481745, 'Overcaps': 0.00023010922330676968, 'Plugs': 0.004734822836652947, 'Press-Fit Closures': 0.14033103155040738, 'Pull Out Spout Closures': 0.18673103495148785, 'Purchased': 0.004008015018522241, 'Screw Closures': 0.25554710454896074, 'Specialty Closures': 0.04259983291120234, 'Tools': 9.744843964809706e-08, 'Wrenches': 4.774973542756756e-08, 'Components': 0.00020562335387639235, 'Unknown SubCategory': 5.454156684290777e-05, 'Proprietary Molded Solutions': 0.0004662079525424436, 'Special Caps': 0.0004046786829205029}
#
# Applying top-down reconciliation...
#
# After Reconciliation:
#   2024-01: Overall=22,086,739, Segments Sum=22,086,739, SubCats Sum=22,086,739
#   2024-02: Overall=21,490,913, Segments Sum=21,490,913, SubCats Sum=21,490,913
#
# Reconciliation completed!

# %%
results = []

for i, (train_df, test_df) in enumerate(rolling_splits):
    print(f"\n🔁 Fold {i+1} | Train: {train_df['Date'].min().date()} to {train_df['Date'].max().date()} | "
      f"Test: {test_df['Date'].min().date()} to {test_df['Date'].max().date()}")
    
    forecast_dates = test_df['Date'].values
    
    # Prepare inputs
    overall_series = train_df.set_index('Date')['Total_Quantity']
    overall_exog = train_df.set_index('Date')[exog_vars]
    
    # Forecast using the same functions
    arima_fc, _, aic_arima = forecast_arima(overall_series, steps=len(forecast_dates))
    sarima_fc, _, aic_sarima = forecast_sarima(overall_series, exog=overall_exog, steps=len(forecast_dates))
    exp_fc, _, aic_exp = forecast_exponential_smoothing(overall_series, steps=len(forecast_dates))
    
    # Ensemble
    ensemble_fc = ensemble_forecast([arima_fc, sarima_fc, exp_fc], [aic_arima, aic_sarima, aic_exp])
    
    # True values
    y_true = test_df['Total_Quantity'].values
    
    # Individual MAPEs
    mape_arima = mean_absolute_percentage_error(y_true, arima_fc.values)
    mape_sarima = mean_absolute_percentage_error(y_true, sarima_fc.values)
    mape_exp = mean_absolute_percentage_error(y_true, exp_fc.values)
    mape_ensemble = mean_absolute_percentage_error(y_true, ensemble_fc.values)

    print(f"MAPE ARIMA: {mape_arima:.2%} | SARIMA: {mape_sarima:.2%} | Exp: {mape_exp:.2%} | Ensemble: {mape_ensemble:.2%}")
    
    # Store all results
    results.append({
        "Fold": i + 1,
        "TrainStart": train_df['Date'].min(),
        "TrainEnd": train_df['Date'].max(),
        "TestStart": test_df['Date'].min(),
        "TestEnd": test_df['Date'].max(),
        "MAPE_ARIMA": mape_arima,
        "MAPE_SARIMA": mape_sarima,
        "MAPE_ExpSmoothing": mape_exp,
        "MAPE_Ensemble": mape_ensemble
    })

# Convert to DataFrame
results_df = pd.DataFrame(results)
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 105, Finished, Available, Finished)
# 2025-07-13:09:46:18,450 ERROR    [shared_platform_utils.py:45] list Notebook failed, status_code: 429, b'{"requestId":"457f1330-b120-47e7-a144-6bd130b92eab","errorCode":"RequestBlocked","message":"Request is blocked by the upstream service until: 7/13/2025 9:46:39 AM (UTC)"}'
# 2025-07-13:09:46:18,450 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 29, in get_experiment_id
#     notebooks: List[O_PBIArtifact] = list_workspace_artifacts(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/shared_platform_utils.py", line 47, in list_workspace_artifacts
#     raise PublicApiException(resp.status_code, error_resp)
# synapse.ml.mlflow.model.shared_artifact.PublicApiException: (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e79d3710>)
# 2025-07-13:09:46:18,451 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e79d3710>)
# 2025-07-13:09:46:18,489 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:46:18,492 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:46:20,527 ERROR    [shared_platform_utils.py:45] list Notebook failed, status_code: 429, b'{"requestId":"3a9246e6-d07f-4632-8e00-117058f15078","errorCode":"RequestBlocked","message":"Request is blocked by the upstream service until: 7/13/2025 9:46:39 AM (UTC)"}'
# 2025-07-13:09:46:20,528 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 29, in get_experiment_id
#     notebooks: List[O_PBIArtifact] = list_workspace_artifacts(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/shared_platform_utils.py", line 47, in list_workspace_artifacts
#     raise PublicApiException(resp.status_code, error_resp)
# synapse.ml.mlflow.model.shared_artifact.PublicApiException: (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7c33a90>)
# 2025-07-13:09:46:20,529 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7c33a90>)
# 2025-07-13:09:46:20,571 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:46:20,573 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:46:20,745 ERROR    [shared_platform_utils.py:45] list Notebook failed, status_code: 429, b'{"requestId":"6fb7cb92-830d-437c-9d10-4e889d5ed69f","errorCode":"RequestBlocked","message":"Request is blocked by the upstream service until: 7/13/2025 9:46:39 AM (UTC)"}'
# 2025-07-13:09:46:20,746 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 29, in get_experiment_id
#     notebooks: List[O_PBIArtifact] = list_workspace_artifacts(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/shared_platform_utils.py", line 47, in list_workspace_artifacts
#     raise PublicApiException(resp.status_code, error_resp)
# synapse.ml.mlflow.model.shared_artifact.PublicApiException: (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7c2c510>)
# 2025-07-13:09:46:20,747 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e7c2c510>)
# 2025-07-13:09:46:26,325 ERROR    [shared_platform_utils.py:45] list Notebook failed, status_code: 429, b'{"requestId":"ac5f2c58-b735-4dd7-bfdd-a82f80d059a8","errorCode":"RequestBlocked","message":"Request is blocked by the upstream service until: 7/13/2025 9:46:39 AM (UTC)"}'
# 2025-07-13:09:46:26,326 ERROR    [default_experiment_registry.py:55] Error find or created notebook/SJD default experiment, please call mlflow.set_experiment to set a valid one before run
# Traceback (most recent call last):
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/default_experiment_registry.py", line 29, in get_experiment_id
#     notebooks: List[O_PBIArtifact] = list_workspace_artifacts(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/synapse_mlflow_utils.py", line 426, in wrapper
#     res = function(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/synapse/ml/mlflow/shared_platform_utils.py", line 47, in list_workspace_artifacts
#     raise PublicApiException(resp.status_code, error_resp)
# synapse.ml.mlflow.model.shared_artifact.PublicApiException: (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e471df90>)
# 2025-07-13:09:46:26,327 ERROR    [synapse_mlflow_utils.py:390] [fabric mlflow plugin]: <class 'synapse.ml.mlflow.default_experiment_registry.SynapseNotebookDefaultExperimentProvider'>.get_experiment_id exception (429, <synapse.ml.mlflow.model.shared_artifact.ErrorResponse object at 0x7c50e471df90>)
# 2025-07-13:09:46:26,367 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>._call_endpoint exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# 2025-07-13:09:46:26,369 ERROR    [synapse_mlflow_utils.py:383] [fabric mlflow plugin]: <class 'mlflow.store.tracking.rest_store.RestStore'>.create_run exception BAD_REQUEST: Response: {'Message': 'Experiment Id should not be empty and needs to be a valid GUID.', 'Source': 'ML', 'error_code': 'BAD_REQUEST'}
# Model weights - ARIMA: 0.310, SARIMA: 0.347, EXP: 0.343
# MAPE ARIMA: 30.19% | SARIMA: 15.02% | Exp: 9.15% | Ensemble: 17.51%

# %%
results_df = pd.DataFrame(results)
print("\n📊 Walk-Forward Validation Summary:")
print(results_df)

print(f"\n✅ Average Ensemble MAPE across {len(results_df)} folds: {results_df['MAPE_Ensemble'].mean():.2%}")
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 106, Finished, Available, Finished)
# 📊 Walk-Forward Validation Summary:
#     Fold TrainStart   TrainEnd  TestStart    TestEnd  MAPE_ARIMA  MAPE_SARIMA  \
# 0      1 2015-01-01 2023-12-01 2024-01-01 2024-02-01    0.223253     0.021448
# 1      2 2015-01-01 2024-01-01 2024-02-01 2024-03-01    0.157436     0.062236
# 2      3 2015-01-01 2024-02-01 2024-03-01 2024-04-01    0.110325     0.062921
# 3      4 2015-01-01 2024-03-01 2024-04-01 2024-05-01    0.068922     0.122846
# 4      5 2015-01-01 2024-04-01 2024-05-01 2024-06-01    0.126222     0.249085
# 5      6 2015-01-01 2024-05-01 2024-06-01 2024-07-01    0.157385     0.118423
# 6      7 2015-01-01 2024-06-01 2024-07-01 2024-08-01    0.175820     0.072539
# 7      8 2015-01-01 2024-07-01 2024-08-01 2024-09-01    0.104929     0.044941
# 8      9 2015-01-01 2024-08-01 2024-09-01 2024-10-01    0.115540     0.087800
# 9     10 2015-01-01 2024-09-01 2024-10-01 2024-11-01    0.035682     0.044230
# 10    11 2015-01-01 2024-10-01 2024-11-01 2024-12-01    0.301888     0.150184
#
#     MAPE_ExpSmoothing  MAPE_Ensemble
# 0            0.220503       0.150471
# 1            0.161605       0.082130
# 2            0.102998       0.087190
# 3            0.100764       0.098588
# 4            0.192534       0.191619
# 5            0.192599       0.155861
# 6            0.159724       0.134464
# 7            0.115533       0.087684
# 8            0.124979       0.109125
# 9            0.105064       0.062442
# 10           0.091464       0.175061
#
# ✅ Average Ensemble MAPE across 11 folds: 12.13%

# %% [markdown]
# ## Forecast Visualization & Results
#
# Let's visualize the hierarchical forecasts and compare them with historical data.

# %%
# # Create comprehensive forecast visualization
# fig = make_subplots(
#     rows=3, cols=1,
#     subplot_titles=('Overall Forecast', 'Customer Segment Forecasts', 'SubCategory Forecasts'),
#     vertical_spacing=0.08,
#     specs=[[{"secondary_y": False}],
#            [{"secondary_y": False}],
#            [{"secondary_y": False}]]
# )

# # Overall forecast plot
# fig.add_trace(
#     go.Scatter(x=overall_ts['Date'], y=overall_ts['Total_Quantity'],
#               mode='lines+markers', name='Historical Total',
#               line=dict(color='darkblue', width=2)),
#     row=1, col=1
# )

# fig.add_trace(
#     go.Scatter(x=overall_forecasts['Date'], y=overall_forecasts['Ensemble'],
#               mode='lines+markers', name='Overall Forecast',
#               line=dict(color='red', width=3, dash='dash')),
#     row=1, col=1
# )

# # Customer segment forecasts
# segment_colors = px.colors.qualitative.Set1
# for i, segment in enumerate(segment_ts['CustomerSegment'].unique()):
#     # Historical data
#     segment_hist = segment_ts[segment_ts['CustomerSegment'] == segment]
#     fig.add_trace(
#         go.Scatter(x=segment_hist['Date'], y=segment_hist['Total_Quantity'],
#                   mode='lines', name=f'{segment} (Historical)',
#                   line=dict(color=segment_colors[i % len(segment_colors)], width=1),
#                   showlegend=False),
#         row=2, col=1
#     )
    
#     # Forecast data
#     segment_forecast = segment_forecasts_reconciled[segment_forecasts_reconciled['CustomerSegment'] == segment]
#     fig.add_trace(
#         go.Scatter(x=segment_forecast['Date'], y=segment_forecast['Ensemble_Reconciled'],
#                   mode='lines+markers', name=f'{segment} Forecast',
#                   line=dict(color=segment_colors[i % len(segment_colors)], width=2, dash='dash')),
#         row=2, col=1
#     )

# # SubCategory forecasts
# subcat_colors = px.colors.qualitative.Set2
# for i, subcat in enumerate(subcategory_ts['SubCategoryName'].unique()):
#     # Historical data
#     subcat_hist = subcategory_ts[subcategory_ts['SubCategoryName'] == subcat]
#     fig.add_trace(
#         go.Scatter(x=subcat_hist['Date'], y=subcat_hist['Total_Quantity'],
#                   mode='lines', name=f'{subcat} (Historical)',
#                   line=dict(color=subcat_colors[i % len(subcat_colors)], width=1),
#                   showlegend=False),
#         row=3, col=1
#     )
    
#     # Forecast data
#     subcat_forecast = subcategory_forecasts_reconciled[subcategory_forecasts_reconciled['SubCategoryName'] == subcat]
#     fig.add_trace(
#         go.Scatter(x=subcat_forecast['Date'], y=subcat_forecast['Ensemble_Reconciled'],
#                   mode='lines+markers', name=f'{subcat} Forecast',
#                   line=dict(color=subcat_colors[i % len(subcat_colors)], width=2, dash='dash')),
#         row=3, col=1
#     )

# fig.update_layout(
#     height=1000,
#     title_text="Hierarchical Sales Forecasting: Historical vs Predicted",
#     showlegend=True,
#     legend=dict(orientation="v", yanchor="top", y=1, xanchor="left", x=1.01)
# )

# fig.update_xaxes(title_text="Date")
# fig.update_yaxes(title_text="Total Quantity")

# fig.show()

# # Print forecast summary
# print("\n=== FORECAST SUMMARY ===")
# print(f"Forecast Period: {FORECAST_DATES[0].strftime('%Y-%m')} to {FORECAST_DATES[-1].strftime('%Y-%m')}")
# print(f"\nOverall Forecast Summary:")
# print(f"  Mean Monthly Forecast: {overall_forecasts['Ensemble'].mean():,.0f}")
# print(f"  Total 12-Month Forecast: {overall_forecasts['Ensemble'].sum():,.0f}")
# print(f"  Min-Max Range: {overall_forecasts['Ensemble'].min():,.0f} - {overall_forecasts['Ensemble'].max():,.0f}")

# print(f"\nCustomer Segment Forecast Summary:")
# for segment in segment_forecasts_reconciled['CustomerSegment'].unique():
#     segment_data = segment_forecasts_reconciled[segment_forecasts_reconciled['CustomerSegment'] == segment]
#     total_forecast = segment_data['Ensemble_Reconciled'].sum()
#     print(f"  {segment}: {total_forecast:,.0f} (12-month total)")

# print(f"\nSubCategory Forecast Summary:")
# for subcat in subcategory_forecasts_reconciled['SubCategoryName'].unique():
#     subcat_data = subcategory_forecasts_reconciled[subcategory_forecasts_reconciled['SubCategoryName'] == subcat]
#     total_forecast = subcat_data['Ensemble_Reconciled'].sum()
#     print(f"  {subcat}: {total_forecast:,.0f} (12-month total)")
# Out:
# StatementMeta(, 7d0bbc76-0c64-4116-8f39-345ab05214a2, 107, Finished, Available, Finished)
